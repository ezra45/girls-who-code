# %% [markdown]
# # WEEK 3 DEMO - GWC Olympics

# %%
import pandas as pd
import matplotlib.pyplot as plt

# CSV URL
csv = "https://tinyurl.com/GWC-olympics"

# Load the CSV while skipping initial rows if the dataset has metadata
# Adjust skiprows if needed (try 0 first, then increase if you see metadata instead of column headers)
# This dataset has metadata for the first 5 rows, so we will set skiprows=5
df = pd.read_csv(csv, skiprows=5)

# Drops useless extra event column - don't worry about this part!
df = df.drop(df.columns[8], axis=1)

# Peek at the first few rows
df.head()
# Out:
#    Year    City      Sport     Discipline        Athlete Name  NOC Gender  \
# 0  1896  Athens    Cycling  Cycling Track       FLAMENG, Léon  FRA    Men
# 1  1896  Athens    Cycling  Cycling Track  KOLETTIS, Georgios  GRE    Men
# 2  1896  Athens  Athletics      Athletics       LANE, Francis  USA    Men
# 3  1896  Athens  Athletics      Athletics    SZOKOLYI, Alajos  HUN    Men
# 4  1896  Athens  Athletics      Athletics       BURKE, Thomas  USA    Men
#
#    Event   Medal  Position
# 0  100km    Gold         1
# 1  100km  Silver         2
# 2   100m  Bronze         3
# 3   100m  Bronze         3
# 4   100m    Gold         1

# %% [markdown]
# # Working with column data

# %% [markdown]
# To view **all of the column names** in the dataframe, use the attribute `df.columns`.
#
# Here is an example:

# %%
print(df.columns)
# Out:
# Index(['Year', 'City', 'Sport', 'Discipline', 'Athlete Name', 'NOC', 'Gender',
#        'Event', 'Medal', 'Position'],
#       dtype='object')

# %% [markdown]
# If you want to view a **single** column within the dataframe, use the method `df["column_name"]`
#
# In this example, we will view the "Athlete Names" column

# %%
df['Athlete Name']
# Out:
# 0             FLAMENG, Léon
# 1        KOLETTIS, Georgios
# 2             LANE, Francis
# 3          SZOKOLYI, Alajos
# 4             BURKE, Thomas
#                 ...
# 27169    LOGOUNOVA, Tatiana
# 27170         SIVKOVA, Anna
# 27171        BOKEL, Claudia
# 27172       DUPLITZER, Imke
# 27173     HEIDEMANN, Britta
# Name: Athlete Name, Length: 27174, dtype: object

# %% [markdown]
# To view the **unique** values in a column, use the method `df["column_name'].unique()`

# %% [markdown]
# We can answer questions like:
#
# What are the types of medals awarded?

# %%
df["Medal"].unique()
# Out:
# array(['Gold', 'Silver', 'Bronze'], dtype=object)

# %% [markdown]
# Or,
#
# What is the time range covered in this dataset?

# %%
df['Year'].unique()
# Out:
# array([1896, 1900, 1904, 1908, 1912, 1920, 1924, 1928, 1932, 1936, 1948,
#        1952, 1956, 1960, 1964, 1968, 1972, 1976, 1980, 1984, 1988, 1992,
#        1996, 2000, 2004])

# %% [markdown]
# To count the **occurrances** of the unique values in a column, use the method `df["column_name"].value_counts()`
#
# If you want the relative frequencies (proportion of each unique value, which sums up to 1) instead of the raw counts, use the method `df["column_name"].value_counts(normalize = True)`

# %% [markdown]
# Across all of the Olympics, how many Gold, Silver, and Bronze medals have there been?

# %%
# Returns the raw count of the occurances of the unique values
print(df["Medal"].value_counts(), "\n\n") # "\n" is an escape character, it
                                          # simply adds a new line!

# Returns the relative frequencies of the occurances of the unique values
print(df["Medal"].value_counts(normalize = True))
# Out:
# Medal
# Gold      9181
# Silver    9014
# Bronze    8979
# Name: count, dtype: int64
#
#
# Medal
# Gold      0.337860
# Silver    0.331714
# Bronze    0.330426
# Name: proportion, dtype: float64

# %% [markdown]
# # Filtering through columns by value

# %% [markdown]
# If you want to **filter** through the columns by value, create a new variable; you can name it anything you want, but it will probably be the most helpful if you name it something relevant to the value you want to access.
#
# After creating a new variable, assign whatever column you want to access and the value within that column.
#
# For example:
# Create a new dataset displaying all athletes who won a "Gold medal".

# %%
# Creating a new variable
# Access the "Medal" column and retrieve only the athletes who won a "Gold medal"
gold_medalists = df[df["Medal"] == "Gold"]


# Displaying the new dataset that you created
# Using the `.head` method only displays the first 5 rows of the dataset,
# Unless you specify a number
gold_medalists.head(10)
# Out:
#     Year    City      Sport     Discipline        Athlete Name  NOC Gender  \
# 0   1896  Athens    Cycling  Cycling Track       FLAMENG, Léon  FRA    Men
# 4   1896  Athens  Athletics      Athletics       BURKE, Thomas  USA    Men
# 6   1896  Athens   Aquatics       Swimming       HAJOS, Alfred  HUN    Men
# 9   1896  Athens   Aquatics       Swimming  MALOKINIS, Ioannis  GRE    Men
# 12  1896  Athens    Cycling  Cycling Track        MASSON, Paul  FRA    Men
# 14  1896  Athens  Athletics      Athletics      CURTIS, Thomas  USA    Men
# 16  1896  Athens    Cycling  Cycling Track       SCHMAL, Adolf  AUT    Men
# 19  1896  Athens   Aquatics       Swimming       HAJOS, Alfred  HUN    Men
# 22  1896  Athens  Athletics      Athletics        FLACK, Edwin  AUS    Men
# 25  1896  Athens    Cycling  Cycling Track        MASSON, Paul  FRA    Men
#
#                          Event Medal  Position
# 0                        100km  Gold         1
# 4                         100m  Gold         1
# 6               100m freestyle  Gold         1
# 9   100m freestyle for sailors  Gold         1
# 12                        10km  Gold         1
# 14                110m hurdles  Gold         1
# 16                12-hour race  Gold         1
# 19             1200m freestyle  Gold         1
# 22                       1500m  Gold         1
# 25              1km time trial  Gold         1

# %% [markdown]
# # Modifying columns

# %% [markdown]
# What if we don't need to see a column anymore? We can **remove** a column. We can do this by using `df.drop()`.
#
# When we do this, we have to enter the name of the column and "axis = 1."
# Axis 1 corresponds to the columns of the data set.
#
# Here, we already know what medal they recieved, so we do not need the position column. Let's remove it!
#
# We created a second variable, `df2`, so that we don't mess with the data in
# our original DataFrame.

# %%
df2 = df.drop("Position", axis=1)
df2
# Out:
#        Year    City      Sport     Discipline        Athlete Name  NOC Gender  \
# 0      1896  Athens    Cycling  Cycling Track       FLAMENG, Léon  FRA    Men
# 1      1896  Athens    Cycling  Cycling Track  KOLETTIS, Georgios  GRE    Men
# 2      1896  Athens  Athletics      Athletics       LANE, Francis  USA    Men
# 3      1896  Athens  Athletics      Athletics    SZOKOLYI, Alajos  HUN    Men
# 4      1896  Athens  Athletics      Athletics       BURKE, Thomas  USA    Men
# ...     ...     ...        ...            ...                 ...  ...    ...
# 27169  2004  Athens    Fencing        Fencing  LOGOUNOVA, Tatiana  RUS  Women
# 27170  2004  Athens    Fencing        Fencing       SIVKOVA, Anna  RUS  Women
# 27171  2004  Athens    Fencing        Fencing      BOKEL, Claudia  GER  Women
# 27172  2004  Athens    Fencing        Fencing     DUPLITZER, Imke  GER  Women
# 27173  2004  Athens    Fencing        Fencing   HEIDEMANN, Britta  GER  Women
#
#            Event   Medal
# 0          100km    Gold
# 1          100km  Silver
# 2           100m  Bronze
# 3           100m  Bronze
# 4           100m    Gold
# ...          ...     ...
# 27169  épée team    Gold
# 27170  épée team    Gold
# 27171  épée team  Silver
# 27172  épée team  Silver
# 27173  épée team  Silver
#
# [27174 rows x 9 columns]

# %% [markdown]
# We can also remove multiple columns.

# %%
df2.drop(["Sport","NOC"], axis=1, inplace = True)
df2
# Out:
#        Year    City     Discipline        Athlete Name Gender      Event  \
# 0      1896  Athens  Cycling Track       FLAMENG, Léon    Men      100km
# 1      1896  Athens  Cycling Track  KOLETTIS, Georgios    Men      100km
# 2      1896  Athens      Athletics       LANE, Francis    Men       100m
# 3      1896  Athens      Athletics    SZOKOLYI, Alajos    Men       100m
# 4      1896  Athens      Athletics       BURKE, Thomas    Men       100m
# ...     ...     ...            ...                 ...    ...        ...
# 27169  2004  Athens        Fencing  LOGOUNOVA, Tatiana  Women  épée team
# 27170  2004  Athens        Fencing       SIVKOVA, Anna  Women  épée team
# 27171  2004  Athens        Fencing      BOKEL, Claudia  Women  épée team
# 27172  2004  Athens        Fencing     DUPLITZER, Imke  Women  épée team
# 27173  2004  Athens        Fencing   HEIDEMANN, Britta  Women  épée team
#
#         Medal
# 0        Gold
# 1      Silver
# 2      Bronze
# 3      Bronze
# 4        Gold
# ...       ...
# 27169    Gold
# 27170    Gold
# 27171  Silver
# 27172  Silver
# 27173  Silver
#
# [27174 rows x 7 columns]

# %% [markdown]
# # Filtering Rows

# %% [markdown]
# We can **filter** by rows as well, and display rows of just what we want.
#
# Here are some examples of displaying rows with one condition.

# %%
# Display the Olympics that happened in 1896
df[df['Year'] == 1896]
# Out:
#      Year    City       Sport     Discipline          Athlete Name  NOC  \
# 0    1896  Athens     Cycling  Cycling Track         FLAMENG, Léon  FRA
# 1    1896  Athens     Cycling  Cycling Track    KOLETTIS, Georgios  GRE
# 2    1896  Athens   Athletics      Athletics         LANE, Francis  USA
# 3    1896  Athens   Athletics      Athletics      SZOKOLYI, Alajos  HUN
# 4    1896  Athens   Athletics      Athletics         BURKE, Thomas  USA
# ..    ...     ...         ...            ...                   ...  ...
# 146  1896  Athens   Athletics      Athletics       CONNOLLY, James  USA
# 147  1896  Athens   Athletics      Athletics    TUFFERI, Alexandre  FRA
# 148  1896  Athens  Gymnastics    Artistic G.  WEINGÄRTNER, Hermann  GER
# 149  1896  Athens  Gymnastics    Artistic G.        SCHUMANN, Carl  GER
# 150  1896  Athens  Gymnastics    Artistic G.         ZUTTER, Louis  SUI
#
#     Gender        Event   Medal  Position
# 0      Men        100km    Gold         1
# 1      Men        100km  Silver         2
# 2      Men         100m  Bronze         3
# 3      Men         100m  Bronze         3
# 4      Men         100m    Gold         1
# ..     ...          ...     ...       ...
# 146    Men  triple jump    Gold         1
# 147    Men  triple jump  Silver         2
# 148    Men        vault  Bronze         3
# 149    Men        vault    Gold         1
# 150    Men        vault  Silver         2
#
# [151 rows x 10 columns]

# %%
# Display all of the Olympics that happened only in Athens
df[df['City'] == 'Athens']
# Out:
#        Year    City      Sport     Discipline        Athlete Name  NOC Gender  \
# 0      1896  Athens    Cycling  Cycling Track       FLAMENG, Léon  FRA    Men
# 1      1896  Athens    Cycling  Cycling Track  KOLETTIS, Georgios  GRE    Men
# 2      1896  Athens  Athletics      Athletics       LANE, Francis  USA    Men
# 3      1896  Athens  Athletics      Athletics    SZOKOLYI, Alajos  HUN    Men
# 4      1896  Athens  Athletics      Athletics       BURKE, Thomas  USA    Men
# ...     ...     ...        ...            ...                 ...  ...    ...
# 27169  2004  Athens    Fencing        Fencing  LOGOUNOVA, Tatiana  RUS  Women
# 27170  2004  Athens    Fencing        Fencing       SIVKOVA, Anna  RUS  Women
# 27171  2004  Athens    Fencing        Fencing      BOKEL, Claudia  GER  Women
# 27172  2004  Athens    Fencing        Fencing     DUPLITZER, Imke  GER  Women
# 27173  2004  Athens    Fencing        Fencing   HEIDEMANN, Britta  GER  Women
#
#            Event   Medal  Position
# 0          100km    Gold         1
# 1          100km  Silver         2
# 2           100m  Bronze         3
# 3           100m  Bronze         3
# 4           100m    Gold         1
# ...          ...     ...       ...
# 27169  épée team    Gold         1
# 27170  épée team    Gold         1
# 27171  épée team  Silver         2
# 27172  épée team  Silver         2
# 27173  épée team  Silver         2
#
# [2149 rows x 10 columns]

# %%
# Display all medalists for one sport
df[df['Sport'] == 'Cycling']
# Out:
#        Year    City    Sport     Discipline            Athlete Name  NOC  \
# 0      1896  Athens  Cycling  Cycling Track           FLAMENG, Léon  FRA
# 1      1896  Athens  Cycling  Cycling Track      KOLETTIS, Georgios  GRE
# 11     1896  Athens  Cycling  Cycling Track           SCHMAL, Adolf  AUT
# 12     1896  Athens  Cycling  Cycling Track            MASSON, Paul  FRA
# 13     1896  Athens  Cycling  Cycling Track           FLAMENG, Léon  FRA
# ...     ...     ...      ...            ...                     ...  ...
# 26686  2004  Athens  Cycling  Cycling Track        SLYUSAREVA, Olga  RUS
# 26687  2004  Athens  Cycling  Cycling Track  GUERRERO MENDEZ, Belem  MEX
# 26830  2004  Athens  Cycling  Cycling Track            MEARES, Anna  AUS
# 26831  2004  Athens  Cycling  Cycling Track       MUENZER, Lori-Ann  CAN
# 26832  2004  Athens  Cycling  Cycling Track       ABASSOVA, Tamilla  RUS
#
#       Gender        Event   Medal  Position
# 0        Men        100km    Gold         1
# 1        Men        100km  Silver         2
# 11       Men         10km  Bronze         3
# 12       Men         10km    Gold         1
# 13       Men         10km  Silver         2
# ...      ...          ...     ...       ...
# 26686  Women  points race    Gold         1
# 26687  Women  points race  Silver         2
# 26830  Women       sprint  Bronze         3
# 26831  Women       sprint    Gold         1
# 26832  Women       sprint  Silver         2
#
# [954 rows x 10 columns]

# %% [markdown]
# If we want to display rows based on multiple conditions, we can use the | and & to represent "or" or "and".
# For example:

# %%
#Display the Olympics that happened in either 1896 OR 2004
df[(df['Year'] == 1896)|(df['Year'] == 2004)]
# Out:
#        Year    City      Sport     Discipline        Athlete Name  NOC Gender  \
# 0      1896  Athens    Cycling  Cycling Track       FLAMENG, Léon  FRA    Men
# 1      1896  Athens    Cycling  Cycling Track  KOLETTIS, Georgios  GRE    Men
# 2      1896  Athens  Athletics      Athletics       LANE, Francis  USA    Men
# 3      1896  Athens  Athletics      Athletics    SZOKOLYI, Alajos  HUN    Men
# 4      1896  Athens  Athletics      Athletics       BURKE, Thomas  USA    Men
# ...     ...     ...        ...            ...                 ...  ...    ...
# 27169  2004  Athens    Fencing        Fencing  LOGOUNOVA, Tatiana  RUS  Women
# 27170  2004  Athens    Fencing        Fencing       SIVKOVA, Anna  RUS  Women
# 27171  2004  Athens    Fencing        Fencing      BOKEL, Claudia  GER  Women
# 27172  2004  Athens    Fencing        Fencing     DUPLITZER, Imke  GER  Women
# 27173  2004  Athens    Fencing        Fencing   HEIDEMANN, Britta  GER  Women
#
#            Event   Medal  Position
# 0          100km    Gold         1
# 1          100km  Silver         2
# 2           100m  Bronze         3
# 3           100m  Bronze         3
# 4           100m    Gold         1
# ...          ...     ...       ...
# 27169  épée team    Gold         1
# 27170  épée team    Gold         1
# 27171  épée team  Silver         2
# 27172  épée team  Silver         2
# 27173  épée team  Silver         2
#
# [2149 rows x 10 columns]

# %%
# Display the medalists for one sport between the years 1986 and 2004
df[(df['Year'] >= 1896) & (df['Year'] <= 2004) & (df['Sport'] == 'Cycling')]
# Out:
#        Year    City    Sport     Discipline            Athlete Name  NOC  \
# 0      1896  Athens  Cycling  Cycling Track           FLAMENG, Léon  FRA
# 1      1896  Athens  Cycling  Cycling Track      KOLETTIS, Georgios  GRE
# 11     1896  Athens  Cycling  Cycling Track           SCHMAL, Adolf  AUT
# 12     1896  Athens  Cycling  Cycling Track            MASSON, Paul  FRA
# 13     1896  Athens  Cycling  Cycling Track           FLAMENG, Léon  FRA
# ...     ...     ...      ...            ...                     ...  ...
# 26686  2004  Athens  Cycling  Cycling Track        SLYUSAREVA, Olga  RUS
# 26687  2004  Athens  Cycling  Cycling Track  GUERRERO MENDEZ, Belem  MEX
# 26830  2004  Athens  Cycling  Cycling Track            MEARES, Anna  AUS
# 26831  2004  Athens  Cycling  Cycling Track       MUENZER, Lori-Ann  CAN
# 26832  2004  Athens  Cycling  Cycling Track       ABASSOVA, Tamilla  RUS
#
#       Gender        Event   Medal  Position
# 0        Men        100km    Gold         1
# 1        Men        100km  Silver         2
# 11       Men         10km  Bronze         3
# 12       Men         10km    Gold         1
# 13       Men         10km  Silver         2
# ...      ...          ...     ...       ...
# 26686  Women  points race    Gold         1
# 26687  Women  points race  Silver         2
# 26830  Women       sprint  Bronze         3
# 26831  Women       sprint    Gold         1
# 26832  Women       sprint  Silver         2
#
# [954 rows x 10 columns]

# %% [markdown]
# If you want to find all rows corresponding to the years 1896, 2000, and 2004:

# %%
years_filter = [1896, 2000, 2004]
filtered_df = df[df['Year'].isin(years_filter)]
filtered_df
# Out:
#        Year    City      Sport     Discipline        Athlete Name  NOC Gender  \
# 0      1896  Athens    Cycling  Cycling Track       FLAMENG, Léon  FRA    Men
# 1      1896  Athens    Cycling  Cycling Track  KOLETTIS, Georgios  GRE    Men
# 2      1896  Athens  Athletics      Athletics       LANE, Francis  USA    Men
# 3      1896  Athens  Athletics      Athletics    SZOKOLYI, Alajos  HUN    Men
# 4      1896  Athens  Athletics      Athletics       BURKE, Thomas  USA    Men
# ...     ...     ...        ...            ...                 ...  ...    ...
# 27169  2004  Athens    Fencing        Fencing  LOGOUNOVA, Tatiana  RUS  Women
# 27170  2004  Athens    Fencing        Fencing       SIVKOVA, Anna  RUS  Women
# 27171  2004  Athens    Fencing        Fencing      BOKEL, Claudia  GER  Women
# 27172  2004  Athens    Fencing        Fencing     DUPLITZER, Imke  GER  Women
# 27173  2004  Athens    Fencing        Fencing   HEIDEMANN, Britta  GER  Women
#
#            Event   Medal  Position
# 0          100km    Gold         1
# 1          100km  Silver         2
# 2           100m  Bronze         3
# 3           100m  Bronze         3
# 4           100m    Gold         1
# ...          ...     ...       ...
# 27169  épée team    Gold         1
# 27170  épée team    Gold         1
# 27171  épée team  Silver         2
# 27172  épée team  Silver         2
# 27173  épée team  Silver         2
#
# [4164 rows x 10 columns]

# %% [markdown]
# # String Methods

# %% [markdown]
# We can replace characters with `.str.replace()`. This is  useful when you want to change something in your data that occurs often.

# %% [markdown]
# This code replaces underscores with spaces in the Event column for better readability:

# %%
df['Event'].str.replace('_', ' ')
# Out:
# 0            100km
# 1            100km
# 2             100m
# 3             100m
# 4             100m
#            ...
# 27169    épée team
# 27170    épée team
# 27171    épée team
# 27172    épée team
# 27173    épée team
# Name: Event, Length: 27174, dtype: object

# %% [markdown]
# We can also filter using `.str.contains()`, which is helpful when searching through your data!

# %% [markdown]
# **Example Problem:**
#
# Larisa Latynina is a legendary Soviet gymnast who holds the record for the most Olympic gold medals (9) in gymnastics and was the overall medal leader (18 total) for decades.
# Filter the dataset to find all of the competitions Latynina was in:

# %%
df_latynina = df[df["Athlete Name"].str.contains("Latynina", case=False)]
df_latynina
# Out:
#        Year                   City       Sport   Discipline      Athlete Name  \
# 9372   1956  Melbourne / Stockholm  Gymnastics  Artistic G.  LATYNINA, Larisa
# 9539   1956  Melbourne / Stockholm  Gymnastics  Artistic G.  LATYNINA, Larisa
# 9679   1956  Melbourne / Stockholm  Gymnastics  Artistic G.  LATYNINA, Larisa
# 9702   1956  Melbourne / Stockholm  Gymnastics  Artistic G.  LATYNINA, Larisa
# 9735   1956  Melbourne / Stockholm  Gymnastics  Artistic G.  LATYNINA, Larisa
# 9741   1956  Melbourne / Stockholm  Gymnastics  Artistic G.  LATYNINA, Larisa
# 10179  1960                   Rome  Gymnastics  Artistic G.  LATYNINA, Larisa
# 10277  1960                   Rome  Gymnastics  Artistic G.  LATYNINA, Larisa
# 10458  1960                   Rome  Gymnastics  Artistic G.  LATYNINA, Larisa
# 10576  1960                   Rome  Gymnastics  Artistic G.  LATYNINA, Larisa
# 10612  1960                   Rome  Gymnastics  Artistic G.  LATYNINA, Larisa
# 10616  1960                   Rome  Gymnastics  Artistic G.  LATYNINA, Larisa
# 11095  1964                  Tokyo  Gymnastics  Artistic G.  LATYNINA, Larisa
# 11195  1964                  Tokyo  Gymnastics  Artistic G.  LATYNINA, Larisa
# 11387  1964                  Tokyo  Gymnastics  Artistic G.  LATYNINA, Larisa
# 11517  1964                  Tokyo  Gymnastics  Artistic G.  LATYNINA, Larisa
# 11551  1964                  Tokyo  Gymnastics  Artistic G.  LATYNINA, Larisa
# 11558  1964                  Tokyo  Gymnastics  Artistic G.  LATYNINA, Larisa
#
#        NOC Gender                     Event   Medal  Position
# 9372   URS  Women           floor exercises    Gold         1
# 9539   URS  Women      individual all-round    Gold         1
# 9679   URS  Women          team competition    Gold         1
# 9702   URS  Women  team, portable apparatus  Bronze         3
# 9735   URS  Women               uneven bars  Silver         2
# 9741   URS  Women                     vault    Gold         1
# 10179  URS  Women              balance beam  Silver         2
# 10277  URS  Women           floor exercises    Gold         1
# 10458  URS  Women      individual all-round    Gold         1
# 10576  URS  Women          team competition    Gold         1
# 10612  URS  Women               uneven bars  Silver         2
# 10616  URS  Women                     vault  Bronze         3
# 11095  URS  Women              balance beam  Bronze         3
# 11195  URS  Women           floor exercises    Gold         1
# 11387  URS  Women      individual all-round  Silver         2
# 11517  URS  Women          team competition    Gold         1
# 11551  URS  Women               uneven bars  Bronze         3
# 11558  URS  Women                     vault  Silver         2

# %% [markdown]
# This code ignores the case of her name. If we didn’t use `case=False` we wouldn’t get anything back because Latynina is all caps in the dataset.

# %% [markdown]
# Another thing we can do is split strings using `.str.split()`. In this example, we are splitting the event names using a space as a delimiter and extracting the first word:

# %%
df['Event_First_Word'] = df['Event'].str.split(' ').str[0]
df['Event_First_Word']
# Out:
# 0        100km
# 1        100km
# 2         100m
# 3         100m
# 4         100m
#          ...
# 27169     épée
# 27170     épée
# 27171     épée
# 27172     épée
# 27173     épée
# Name: Event_First_Word, Length: 27174, dtype: object

# %% [markdown]
# # Sorting Dataframes

# %% [markdown]
# We can also sort the data frame! This can be helpful for many reasons and help us search through the set more efficiently. We can do this with the `sort_values()` method.
#
# First, let's start by sorting using the column name.

# %%
# Sort data set by athlete names
df.sort_values("Athlete Name")
# Out:
#       Year      City       Sport   Discipline              Athlete Name  NOC  \
# 611   1900     Paris  Tug of War   Tug of War              AABYE, Edgar  ZZX
# 3060  1920   Antwerp    Aquatics     Swimming     AALTONEN, Arvo Ossian  FIN
# 2963  1920   Antwerp    Aquatics     Swimming     AALTONEN, Arvo Ossian  FIN
# 7792  1948    London  Gymnastics  Artistic G.  AALTONEN, Paavo Johannes  FIN
# 7906  1948    London  Gymnastics  Artistic G.  AALTONEN, Paavo Johannes  FIN
# ...    ...       ...         ...          ...                       ...  ...
# 275   1900     Paris    Shooting     Shooting                ÖSTMO, Ole  NOR
# 443   1900     Paris    Shooting     Shooting                ÖSTMO, Ole  NOR
# 280   1900     Paris    Shooting     Shooting                ÖSTMO, Ole  NOR
# 268   1900     Paris    Shooting     Shooting                ÖSTMO, Ole  NOR
# 8125  1952  Helsinki    Aquatics     Swimming         ÖSTRAND, Per-Olof  SWE
#
#      Gender                          Event   Medal  Position
# 611     Men                     tug of war    Gold         1
# 3060    Men              400m breaststroke  Bronze         3
# 2963    Men              200m breaststroke  Bronze         3
# 7792    Men           individual all-round  Bronze         3
# 7906    Men               team competition    Gold         1
# ...     ...                            ...     ...       ...
# 275     Men        army rifle, 300m, prone  Bronze         3
# 443     Men               free rifle, team  Silver         2
# 280     Men     army rifle, 300m, standing  Silver         2
# 268     Men  army rifle, 300m, 3 positions  Bronze         3
# 8125    Men                 400m freestyle  Bronze         3
#
# [27174 rows x 10 columns]

# %% [markdown]
# Now, let's say we want it specifically to be ascending or descending order. In the previous example, it alphabetizes their names. But what if we want it from the bottom to the top? We can set **ascending** equal to **False**.

# %%
# Sort by athlete names, descending
df.sort_values("Athlete Name", ascending = False)
# Out:
#       Year      City       Sport   Discipline              Athlete Name  NOC  \
# 8125  1952  Helsinki    Aquatics     Swimming         ÖSTRAND, Per-Olof  SWE
# 268   1900     Paris    Shooting     Shooting                ÖSTMO, Ole  NOR
# 443   1900     Paris    Shooting     Shooting                ÖSTMO, Ole  NOR
# 275   1900     Paris    Shooting     Shooting                ÖSTMO, Ole  NOR
# 280   1900     Paris    Shooting     Shooting                ÖSTMO, Ole  NOR
# ...    ...       ...         ...          ...                       ...  ...
# 7967  1948    London  Gymnastics  Artistic G.  AALTONEN, Paavo Johannes  FIN
# 7792  1948    London  Gymnastics  Artistic G.  AALTONEN, Paavo Johannes  FIN
# 2963  1920   Antwerp    Aquatics     Swimming     AALTONEN, Arvo Ossian  FIN
# 3060  1920   Antwerp    Aquatics     Swimming     AALTONEN, Arvo Ossian  FIN
# 611   1900     Paris  Tug of War   Tug of War              AABYE, Edgar  ZZX
#
#      Gender                          Event   Medal  Position
# 8125    Men                 400m freestyle  Bronze         3
# 268     Men  army rifle, 300m, 3 positions  Bronze         3
# 443     Men               free rifle, team  Silver         2
# 275     Men        army rifle, 300m, prone  Bronze         3
# 280     Men     army rifle, 300m, standing  Silver         2
# ...     ...                            ...     ...       ...
# 7967    Men                          vault    Gold         1
# 7792    Men           individual all-round  Bronze         3
# 2963    Men              200m breaststroke  Bronze         3
# 3060    Men              400m breaststroke  Bronze         3
# 611     Men                     tug of war    Gold         1
#
# [27174 rows x 10 columns]

# %% [markdown]
# We can also manipulate more than one column, and individually decide if we want them to be ascending or descending.

# %%
# sort by year and athlete name
df.sort_values(by = ["Year", "Athlete Name"])
# Out:
#        Year    City       Sport    Discipline              Athlete Name  NOC  \
# 20     1896  Athens    Aquatics      Swimming          ANDREOU, Joannis  GRE
# 103    1896  Athens  Gymnastics   Artistic G.  ANDRIAKOPOULOS, Nicolaos  GRE
# 141    1896  Athens  Gymnastics   Artistic G.  ANDRIAKOPOULOS, Nicolaos  GRE
# 142    1896  Athens  Gymnastics   Artistic G.    ATHANASOPOULOS, Spyros  GRE
# 79     1896  Athens     Cycling  Cycling Road            BATTEL, Edward  GBR
# ...     ...     ...         ...           ...                       ...  ...
# 25753  2004  Athens      Boxing        Boxing             ZUYEV, Viktar  BLR
# 25748  2004  Athens        Judo          Judo          ZVIADAURI, Zurab  GEO
# 26570  2004  Athens      Hockey        Hockey              ZWEHL, Julia  GER
# 25440  2004  Athens    Aquatics      Swimming       ZWERING, Klaas-Erik  NED
# 25587  2004  Athens   Athletics     Athletics            ZYKINA, Olesya  RUS
#
#       Gender                     Event   Medal  Position
# 20       Men           1200m freestyle  Silver         2
# 103      Men             rope climbing    Gold         1
# 141      Men       team, parallel bars  Silver         2
# 142      Men       team, parallel bars  Silver         2
# 79       Men      individual road race  Bronze         3
# ...      ...                       ...     ...       ...
# 25753    Men   81 - 91kg (heavyweight)  Silver         2
# 25748    Men  81 - 90kg (middleweight)    Gold         1
# 26570  Women                    hockey    Gold         1
# 25440    Men    4x100m freestyle relay  Silver         2
# 25587  Women              4x400m relay  Silver         2
#
# [27174 rows x 10 columns]

# %%
# Sort year in descending order, and athlete name in ascending order
df.sort_values(by = ["Year", "Athlete Name"], ascending = [False, True])
# Out:
#        Year    City       Sport       Discipline        Athlete Name  NOC  \
# 25212  2004  Athens   Wrestling  Wrestling Free.       ABAS, Stephen  USA
# 26832  2004  Athens     Cycling    Cycling Track   ABASSOVA, Tamilla  RUS
# 25418  2004  Athens   Taekwondo        Taekwondo       ABDALLAH, Nia  USA
# 25726  2004  Athens   Wrestling  Wrestling Gre-R     ABRAHAMIAN, Ara  SWE
# 26997  2004  Athens  Volleyball       Volleyball      ABRAMOV, Pavel  RUS
# ...     ...     ...         ...              ...                 ...  ...
# 104    1896  Athens  Gymnastics      Artistic G.  XENAKIS, Thomasios  GRE
# 144    1896  Athens  Gymnastics      Artistic G.  XENAKIS, Thomasios  GRE
# 92     1896  Athens  Gymnastics      Artistic G.       ZUTTER, Louis  SUI
# 97     1896  Athens  Gymnastics      Artistic G.       ZUTTER, Louis  SUI
# 150    1896  Athens  Gymnastics      Artistic G.       ZUTTER, Louis  SUI
#
#       Gender                Event   Medal  Position
# 25212    Men               - 55kg  Silver         2
# 26832  Women               sprint  Silver         2
# 25418  Women           49 - 57 kg  Silver         2
# 25726    Men            74 - 84kg  Silver         2
# 26997    Men           volleyball  Bronze         3
# ...      ...                  ...     ...       ...
# 104      Men        rope climbing  Silver         2
# 144      Men  team, parallel bars  Silver         2
# 92       Men        parallel bars  Silver         2
# 97       Men         pommel horse    Gold         1
# 150      Men                vault  Silver         2
#
# [27174 rows x 10 columns]
